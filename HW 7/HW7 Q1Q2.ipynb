# %%
import numpy as np
import pyomo.environ as pe

# %%
model1 = pe.ConcreteModel()
model1.IDXflow = pe.RangeSet(9)
model1.IDXchem = ['A', 'B', 'C']
model1.IDXprocess = [1, 2, 3]
model1.f = pe.Var(model1.IDXflow, within=pe.NonNegativeReals)  # flows
model1.y = pe.Var(model1.IDXprocess, within=pe.Binary)  # process selection

fixed_cost = {1: 10, 2: 15, 3: 20}
variable_cost = {1: 2.5, 2: 4.0, 3: 5.5}
raw_cost = {'A': 5, 'B': 9.5, 'C': 18}
conversion = {1: 0.90, 2: 0.82, 3: 0.95}

model1.fc = pe.Param(model1.IDXprocess, initialize=fixed_cost)
model1.vc = pe.Param(model1.IDXprocess, initialize=variable_cost)
model1.rc = pe.Param(model1.IDXchem, initialize=raw_cost)
model1.x = pe.Param(model1.IDXprocess, initialize=conversion)

# %%
def obj_rule(m):
    return m.rc['C'] * m.f[9] \
           - (m.rc['A'] + m.vc[1]) * m.f[1] \
           - m.rc['B'] * m.f[3] \
           - m.vc[2] * m.f[5] \
           - m.vc[3] * m.f[6] \
           - sum(m.fc[i] * m.y[i] for i in m.IDXprocess)  # revenue - raw material cost - variable cost - fixed cost
model1.obj = pe.Objective(rule=obj_rule, sense=pe.maximize)

# %%
def max_demand_rule(m):
    return m.f[9] <= 10
model1.max_demand = pe.Constraint(rule=max_demand_rule)  # in case 1


def max_supply_rule(m):
    return m.f[1] <= 16
model1.max_supply = pe.Constraint(rule=max_supply_rule)


# mass balance - chemical process
def mass_balanceI_rule(m):
    return m.f[2] == m.x[1] * m.f[1]
model1.mass_balanceI = pe.Constraint(rule=mass_balanceI_rule)


def mass_balanceII_rule(m):
    return m.f[7] == m.x[2] * m.f[5]
model1.mass_balanceII = pe.Constraint(rule=mass_balanceII_rule)


def mass_balanceIII_rule(m):
    return m.f[8] == m.x[3] * m.f[6]
model1.mass_balanceIII = pe.Constraint(rule=mass_balanceIII_rule)


# mass balance - mix and split
def mass_balanceB1_rule(m):
    return m.f[4] == m.f[5] + m.f[6]
model1.mass_balanceB1 = pe.Constraint(rule=mass_balanceB1_rule)


def mass_balanceB2_rule(m):
    return m.f[4] == m.f[2] + m.f[3]
model1.mass_balanceB2 = pe.Constraint(rule=mass_balanceB2_rule)

def mass_balanceC_rule(m):
    return m.f[9] == m.f[7] + m.f[8]
model1.mass_balanceC = pe.Constraint(rule=mass_balanceC_rule)


# process selection
def upper_bound1_rule(m):
    return m.f[1] <= 16 * m.y[1]
model1.upperbound1 = pe.Constraint(rule=upper_bound1_rule)


def upper_bound2_rule(m):
    return m.f[5] <= 10/m.x[2] * m.y[2]
model1.upperbound2 = pe.Constraint(rule=upper_bound2_rule)


def upper_bound3_rule(m):
    return m.f[6] <= 10/m.x[3] * m.y[3]
model1.upperbound3 = pe.Constraint(rule=upper_bound3_rule)


def exclusive_strategy_rule(m):
    return sum(m.y[i] for i in [2, 3]) == 1
model1.exclusive_strategy = pe.Constraint(rule=exclusive_strategy_rule)  #XOR

# %%
# 1.1
solver1 = pe.SolverFactory('gurobi')
result_obj = solver1.solve(model1, tee=True)
model1.pprint()
print(result_obj) # remember to * 100
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-03-01
# Read LP format model from file /var/folders/b0/z7p69zhx459bv344t3ml6by00000gp/T/tmp2pq_xh98.pyomo.lp
# Reading time = 0.00 seconds
# x13: 13 rows, 13 columns, 26 nonzeros
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[rosetta2])
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 13 rows, 13 columns and 26 nonzeros
# Model fingerprint: 0xb814a06e
# Variable types: 10 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [8e-01, 2e+01]
#   Objective range  [4e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Presolve removed 8 rows and 8 columns
# Presolve time: 0.00s
# Presolved: 5 rows, 5 columns, 11 nonzeros
# Variable types: 3 continuous, 2 integer (2 binary)
# Found heuristic solution: objective 4.5934959
#
# Root relaxation: objective 5.754386e+00, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    5.75439    0    1    4.59350    5.75439  25.3%     -    0s
#
# Explored 1 nodes (2 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 10 (of 10 available processors)
#
# Solution count 1: 4.5935
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.593495934959e+00, best bound 4.593495934959e+00, gap 0.0000%
# 5 Set Declarations
#     fc_index : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    3 : {1, 2, 3}
#     rc_index : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    3 : {'A', 'B', 'C'}
#     vc_index : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    3 : {1, 2, 3}
#     x_index : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    3 : {1, 2, 3}
#     y_index : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    3 : {1, 2, 3}
#
# 1 RangeSet Declarations
#     IDXflow : Dimen=1, Size=9, Bounds=(1, 9)
#         Key  : Finite : Members
#         None :   True :   [1:9]
#
# 4 Param Declarations
#     fc : Size=3, Index=fc_index, Domain=Any, Default=None, Mutable=False
#         Key : Value
#           1 :    10
#           2 :    15
#           3 :    20
#     rc : Size=3, Index=rc_index, Domain=Any, Default=None, Mutable=False
#         Key : Value
#           A :     5
#           B :   9.5
#           C :    18
#     vc : Size=3, Index=vc_index, Domain=Any, Default=None, Mutable=False
#         Key : Value
#           1 :   2.5
#           2 :   4.0
#           3 :   5.5
#     x : Size=3, Index=x_index, Domain=Any, Default=None, Mutable=False
#         Key : Value
#           1 :   0.9
#           2 :  0.82
#           3 :  0.95
#
# 2 Var Declarations
#     f : Size=9, Index=IDXflow
#         Key : Lower : Value              : Upper : Fixed : Stale : Domain
#           1 :     0 : 13.550135501355014 :  None : False : False : NonNegativeReals
#           2 :     0 : 12.195121951219512 :  None : False : False : NonNegativeReals
#           3 :     0 :                0.0 :  None : False : False : NonNegativeReals
#           4 :     0 : 12.195121951219512 :  None : False : False : NonNegativeReals
#           5 :     0 : 12.195121951219512 :  None : False : False : NonNegativeReals
#           6 :     0 :                0.0 :  None : False : False : NonNegativeReals
#           7 :     0 :               10.0 :  None : False : False : NonNegativeReals
#           8 :     0 :                0.0 :  None : False : False : NonNegativeReals
#           9 :     0 :               10.0 :  None : False : False : NonNegativeReals
#     y : Size=3, Index=y_index
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           1 :     0 :   1.0 :     1 : False : False : Binary
#           2 :     0 :   1.0 :     1 : False : False : Binary
#           3 :     0 :   0.0 :     1 : False : False : Binary
#
# 1 Objective Declarations
#     obj : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : maximize : 18*f[9] - 7.5*f[1] - 9.5*f[3] - 4.0*f[5] - 5.5*f[6] - (10*y[1] + 15*y[2] + 20*y[3])
#
# 12 Constraint Declarations
#     exclusive_strategy : Size=1, Index=None, Active=True
#         Key  : Lower : Body        : Upper : Active
#         None :   1.0 : y[2] + y[3] :   1.0 :   True
#     mass_balanceB1 : Size=1, Index=None, Active=True
#         Key  : Lower : Body                 : Upper : Active
#         None :   0.0 : f[4] - (f[5] + f[6]) :   0.0 :   True
#     mass_balanceB2 : Size=1, Index=None, Active=True
#         Key  : Lower : Body                 : Upper : Active
#         None :   0.0 : f[4] - (f[2] + f[3]) :   0.0 :   True
#     mass_balanceC : Size=1, Index=None, Active=True
#         Key  : Lower : Body                 : Upper : Active
#         None :   0.0 : f[9] - (f[7] + f[8]) :   0.0 :   True
#     mass_balanceI : Size=1, Index=None, Active=True
#         Key  : Lower : Body            : Upper : Active
#         None :   0.0 : f[2] - 0.9*f[1] :   0.0 :   True
#     mass_balanceII : Size=1, Index=None, Active=True
#         Key  : Lower : Body             : Upper : Active
#         None :   0.0 : f[7] - 0.82*f[5] :   0.0 :   True
#     mass_balanceIII : Size=1, Index=None, Active=True
#         Key  : Lower : Body             : Upper : Active
#         None :   0.0 : f[8] - 0.95*f[6] :   0.0 :   True
#     max_demand : Size=1, Index=None, Active=True
#         Key  : Lower : Body : Upper : Active
#         None :  -Inf : f[9] :  10.0 :   True
#     max_supply : Size=1, Index=None, Active=True
#         Key  : Lower : Body : Upper : Active
#         None :  -Inf : f[1] :  16.0 :   True
#     upperbound1 : Size=1, Index=None, Active=True
#         Key  : Lower : Body           : Upper : Active
#         None :  -Inf : f[1] - 16*y[1] :   0.0 :   True
#     upperbound2 : Size=1, Index=None, Active=True
#         Key  : Lower : Body                           : Upper : Active
#         None :  -Inf : f[5] - 12.195121951219512*y[2] :   0.0 :   True
#     upperbound3 : Size=1, Index=None, Active=True
#         Key  : Lower : Body                           : Upper : Active
#         None :  -Inf : f[6] - 10.526315789473685*y[3] :   0.0 :   True
#
# 25 Declarations: IDXflow f y_index y fc_index fc vc_index vc rc_index rc x_index x obj max_demand max_supply mass_balanceI mass_balanceII mass_balanceIII mass_balanceB1 mass_balanceB2 mass_balanceC upperbound1 upperbound2 upperbound3 exclusive_strategy
#
# Problem:
# - Name: x13
#   Lower bound: 4.59349593495935
#   Upper bound: 4.593495934959357
#   Number of objectives: 1
#   Number of constraints: 13
#   Number of variables: 13
#   Number of binary variables: 3
#   Number of integer variables: 3
#   Number of continuous variables: 10
#   Number of nonzeros: 26
#   Sense: maximize
# Solver:
# - Status: ok
#   Return code: 0
#   Message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#   Termination condition: optimal
#   Termination message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#   Wall time: 0.0024161338806152344
#   Error rc: 0
#   Time: 0.0901639461517334
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0

# %%
# split the original flow 9 into two flows with selling price 1.8 and 1.5
# f9[1] must <= 10, f9[2] must <= 5
model1 = pe.ConcreteModel()
model1.IDXflow = pe.RangeSet(8)
model1.IDXchem = ['A', 'B', 'C1', 'C2']
model1.IDXprocess = [1, 2, 3]
model1.f = pe.Var(model1.IDXflow, within=pe.NonNegativeReals)
model1.y = pe.Var(model1.IDXprocess, within=pe.Binary)
model1.f9 = pe.Var([1, 2], within=pe.NonNegativeReals)

fixed_cost = {1: 10, 2: 15, 3: 20}
variable_cost = {1: 2.5, 2: 4.0, 3: 5.5}
raw_cost = {'A': 5.0, 'B': 9.5, 'C1': 18, 'C2': 15}
conversion = {1: 0.90, 2: 0.82, 3: 0.95}

model1.fc = pe.Param(model1.IDXprocess, initialize=fixed_cost)
model1.vc = pe.Param(model1.IDXprocess, initialize=variable_cost)
model1.rc = pe.Param(model1.IDXchem, initialize=raw_cost)
model1.x = pe.Param(model1.IDXprocess, initialize=conversion)

# %%
# because the selling price of f9[1] is higher than that of f9[2]
# it will automatically choose f9[1] to be the maximum before increasing f9[2]
def obj_rule(m):
    return m.rc['C1'] * m.f9[1] +  m.rc['C2'] * m.f9[2] \
           - (m.rc['A'] + m.vc[1]) * m.f[1] \
           - m.rc['B'] * m.f[3] \
           - m.vc[2] * m.f[5] \
           - m.vc[3] * m.f[6] \
           - sum(m.fc[i] * m.y[i] for i in m.IDXprocess)
model1.obj = pe.Objective(rule=obj_rule, sense=pe.maximize)

# %%
def max_demand1_rule(m):
    return m.f9[1] <= 10
model1.max_demand1 = pe.Constraint(rule=max_demand1_rule) # case 2


def max_demand2_rule(m):
    return m.f9[2] <= 5
model1.max_demand2 = pe.Constraint(rule=max_demand2_rule)


def max_supply_rule(m):
    return m.f[1] <= 16
model1.max_supply = pe.Constraint(rule=max_supply_rule)


# mass balance - chemical process
def mass_balanceI_rule(m):
    return m.f[2] == m.x[1] * m.f[1]
model1.mass_balanceI = pe.Constraint(rule=mass_balanceI_rule)


def mass_balanceII_rule(m):
    return m.f[7] == m.x[2] * m.f[5]
model1.mass_balanceII = pe.Constraint(rule=mass_balanceII_rule)


def mass_balanceIII_rule(m):
    return m.f[8] == m.x[3] * m.f[6]
model1.mass_balanceIII = pe.Constraint(rule=mass_balanceIII_rule)


# mass balance - mix and split
def mass_balanceB1_rule(m):
    return m.f[4] == m.f[5] + m.f[6]
model1.mass_balanceB1 = pe.Constraint(rule=mass_balanceB1_rule)


def mass_balanceB2_rule(m):
    return m.f[4] == m.f[2] + m.f[3]
model1.mass_balanceB2 = pe.Constraint(rule=mass_balanceB2_rule)


def mass_balanceC_rule(m):
    return m.f9[1] + m.f9[2] == m.f[7] + m.f[8]
model1.mass_balanceC = pe.Constraint(rule=mass_balanceC_rule)


def upper_bound1_rule(m):
    return m.f[1] <= 16 * m.y[1]
model1.upperbound1 = pe.Constraint(rule=upper_bound1_rule)


def upper_bound2_rule(m):
    return m.f[5] <= 15/m.x[2] * m.y[2]
model1.upperbound2 = pe.Constraint(rule=upper_bound2_rule)


def upper_bound3_rule(m):
    return m.f[6] <= 15/m.x[3] * m.y[3]
model1.upperbound3 = pe.Constraint(rule=upper_bound3_rule)


def exclusive_strategy_rule(m):
    return sum(m.y[i] for i in [2, 3]) == 1
model1.exclusive_strategy = pe.Constraint(rule=exclusive_strategy_rule)

# %%
# 1.2
solver1 = pe.SolverFactory('gurobi')
result_obj = solver1.solve(model1, tee=True)
model1.pprint()
print(result_obj)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-03-01
# Read LP format model from file /var/folders/b0/z7p69zhx459bv344t3ml6by00000gp/T/tmpnhpx04ct.pyomo.lp
# Reading time = 0.00 seconds
# x14: 14 rows, 14 columns, 28 nonzeros
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[rosetta2])
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 14 rows, 14 columns and 28 nonzeros
# Model fingerprint: 0x2665916a
# Variable types: 11 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [8e-01, 2e+01]
#   Objective range  [4e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Presolve removed 9 rows and 7 columns
# Presolve time: 0.00s
# Presolved: 5 rows, 7 columns, 13 nonzeros
# Variable types: 5 continuous, 2 integer (2 binary)
# Found heuristic solution: objective 4.5934959
#
# Root relaxation: objective 8.742690e+00, 3 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    8.74269    0    2    4.59350    8.74269  90.3%     -    0s
# H    0     0                       6.0000000    8.74269  45.7%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Implied bound: 1
#
# Explored 1 nodes (3 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 10 (of 10 available processors)
#
# Solution count 2: 6 4.5935
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.000000000000e+00, best bound 6.000000000000e+00, gap 0.0000%
# 6 Set Declarations
#     f9_index : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    2 : {1, 2}
#     fc_index : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    3 : {1, 2, 3}
#     rc_index : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    4 : {'A', 'B', 'C1', 'C2'}
#     vc_index : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    3 : {1, 2, 3}
#     x_index : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    3 : {1, 2, 3}
#     y_index : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    3 : {1, 2, 3}
#
# 1 RangeSet Declarations
#     IDXflow : Dimen=1, Size=8, Bounds=(1, 8)
#         Key  : Finite : Members
#         None :   True :   [1:8]
#
# 4 Param Declarations
#     fc : Size=3, Index=fc_index, Domain=Any, Default=None, Mutable=False
#         Key : Value
#           1 :    10
#           2 :    15
#           3 :    20
#     rc : Size=4, Index=rc_index, Domain=Any, Default=None, Mutable=False
#         Key : Value
#           A :   5.0
#           B :   9.5
#          C1 :    18
#          C2 :    15
#     vc : Size=3, Index=vc_index, Domain=Any, Default=None, Mutable=False
#         Key : Value
#           1 :   2.5
#           2 :   4.0
#           3 :   5.5
#     x : Size=3, Index=x_index, Domain=Any, Default=None, Mutable=False
#         Key : Value
#           1 :   0.9
#           2 :  0.82
#           3 :  0.95
#
# 3 Var Declarations
#     f : Size=8, Index=IDXflow
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           1 :     0 :  16.0 :  None : False : False : NonNegativeReals
#           2 :     0 :  14.4 :  None : False : False : NonNegativeReals
#           3 :     0 :   0.0 :  None : False : False : NonNegativeReals
#           4 :     0 :  14.4 :  None : False : False : NonNegativeReals
#           5 :     0 :   0.0 :  None : False : False : NonNegativeReals
#           6 :     0 :  14.4 :  None : False : False : NonNegativeReals
#           7 :     0 :   0.0 :  None : False : False : NonNegativeReals
#           8 :     0 : 13.68 :  None : False : False : NonNegativeReals
#     f9 : Size=2, Index=f9_index
#         Key : Lower : Value              : Upper : Fixed : Stale : Domain
#           1 :     0 :               10.0 :  None : False : False : NonNegativeReals
#           2 :     0 : 3.6799999999999997 :  None : False : False : NonNegativeReals
#     y : Size=3, Index=y_index
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           1 :     0 :   1.0 :     1 : False : False : Binary
#           2 :     0 :  -0.0 :     1 : False : False : Binary
#           3 :     0 :   1.0 :     1 : False : False : Binary
#
# 1 Objective Declarations
#     obj : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : maximize : 18*f9[1] + 15*f9[2] - 7.5*f[1] - 9.5*f[3] - 4.0*f[5] - 5.5*f[6] - (10*y[1] + 15*y[2] + 20*y[3])
#
# 13 Constraint Declarations
#     exclusive_strategy : Size=1, Index=None, Active=True
#         Key  : Lower : Body        : Upper : Active
#         None :   1.0 : y[2] + y[3] :   1.0 :   True
#     mass_balanceB1 : Size=1, Index=None, Active=True
#         Key  : Lower : Body                 : Upper : Active
#         None :   0.0 : f[4] - (f[5] + f[6]) :   0.0 :   True
#     mass_balanceB2 : Size=1, Index=None, Active=True
#         Key  : Lower : Body                 : Upper : Active
#         None :   0.0 : f[4] - (f[2] + f[3]) :   0.0 :   True
#     mass_balanceC : Size=1, Index=None, Active=True
#         Key  : Lower : Body                          : Upper : Active
#         None :   0.0 : f9[1] + f9[2] - (f[7] + f[8]) :   0.0 :   True
#     mass_balanceI : Size=1, Index=None, Active=True
#         Key  : Lower : Body            : Upper : Active
#         None :   0.0 : f[2] - 0.9*f[1] :   0.0 :   True
#     mass_balanceII : Size=1, Index=None, Active=True
#         Key  : Lower : Body             : Upper : Active
#         None :   0.0 : f[7] - 0.82*f[5] :   0.0 :   True
#     mass_balanceIII : Size=1, Index=None, Active=True
#         Key  : Lower : Body             : Upper : Active
#         None :   0.0 : f[8] - 0.95*f[6] :   0.0 :   True
#     max_demand1 : Size=1, Index=None, Active=True
#         Key  : Lower : Body  : Upper : Active
#         None :  -Inf : f9[1] :  10.0 :   True
#     max_demand2 : Size=1, Index=None, Active=True
#         Key  : Lower : Body  : Upper : Active
#         None :  -Inf : f9[2] :   5.0 :   True
#     max_supply : Size=1, Index=None, Active=True
#         Key  : Lower : Body : Upper : Active
#         None :  -Inf : f[1] :  16.0 :   True
#     upperbound1 : Size=1, Index=None, Active=True
#         Key  : Lower : Body           : Upper : Active
#         None :  -Inf : f[1] - 16*y[1] :   0.0 :   True
#     upperbound2 : Size=1, Index=None, Active=True
#         Key  : Lower : Body                          : Upper : Active
#         None :  -Inf : f[5] - 18.29268292682927*y[2] :   0.0 :   True
#     upperbound3 : Size=1, Index=None, Active=True
#         Key  : Lower : Body                           : Upper : Active
#         None :  -Inf : f[6] - 15.789473684210527*y[3] :   0.0 :   True
#
# 28 Declarations: IDXflow f y_index y f9_index f9 fc_index fc vc_index vc rc_index rc x_index x obj max_demand1 max_demand2 max_supply mass_balanceI mass_balanceII mass_balanceIII mass_balanceB1 mass_balanceB2 mass_balanceC upperbound1 upperbound2 upperbound3 exclusive_strategy
#
# Problem:
# - Name: x14
#   Lower bound: 5.999999999999986
#   Upper bound: 6.0
#   Number of objectives: 1
#   Number of constraints: 14
#   Number of variables: 14
#   Number of binary variables: 3
#   Number of integer variables: 3
#   Number of continuous variables: 11
#   Number of nonzeros: 28
#   Sense: maximize
# Solver:
# - Status: ok
#   Return code: 0
#   Message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#   Termination condition: optimal
#   Termination message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#   Wall time: 0.00456690788269043
#   Error rc: 0
#   Time: 0.08142900466918945
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0

# %%
model2 = pe.ConcreteModel()
model2.IDXt = pe.RangeSet(6)

demand = {1: 10, 2: 40, 3: 20, 4: 5, 5: 5, 6: 15}
fixed_cost = {1: 50, 2: 50, 3: 50, 4: 50, 5: 50, 6: 50}
production_cost = {1: 1, 2: 3, 3: 3, 4: 1, 5: 1, 6: 1}
holding_cost = {1: 2, 2: 2, 3: 2, 4: 2, 5: 2, 6: 2}

model2.d = pe.Param(model2.IDXt, initialize=demand)
model2.f = pe.Param(model2.IDXt, initialize=fixed_cost)
model2.p = pe.Param(model2.IDXt, initialize=production_cost)
model2.h = pe.Param(model2.IDXt, initialize=holding_cost)
model2.C = pe.Param(initialize=25)

model2.y = pe.Var(model2.IDXt, within=pe.NonNegativeReals)
model2.s = pe.Var(model2.IDXt, within=pe.NonNegativeReals)
model2.x = pe.Var(model2.IDXt, within=pe.Binary)

# %%
def obj_rule(m):
    return sum(m.p[t] * m.y[t] + m.h[t] * m.s[t] + m.f[t] * m.x[t] for t in m.IDXt)
model2.obj = pe.Objective(rule=obj_rule, sense=pe.minimize)

# %%
def balance_rule(m, t):
    if t == 1:
        return 0 + m.y[t] == m.d[t] + m.s[t]
    else:
        return m.s[t-1] + m.y[t] == m.d[t] + m.s[t]    
model2.balance = pe.Constraint(model2.IDXt, rule=balance_rule)

def production_limit_rule(m, t):
    return m.y[t] <= m.C * m.x[t]
model2.production_limit = pe.Constraint(model2.IDXt, rule=production_limit_rule)

# %%
# 2
solver2 = pe.SolverFactory('gurobi')
result_obj = solver2.solve(model2, tee=True)
model2.pprint()
print(result_obj)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-03-01
# Read LP format model from file /var/folders/b0/z7p69zhx459bv344t3ml6by00000gp/T/tmpq7__50i0.pyomo.lp
# Reading time = 0.00 seconds
# x19: 13 rows, 19 columns, 30 nonzeros
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[rosetta2])
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 13 rows, 19 columns and 30 nonzeros
# Model fingerprint: 0x7b2980b9
# Variable types: 13 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 5e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+01]
# Presolve removed 9 rows and 13 columns
# Presolve time: 0.00s
# Presolved: 4 rows, 6 columns, 9 nonzeros
# Variable types: 0 continuous, 6 integer (3 binary)
# Found heuristic solution: objective 485.0000000
#
# Root relaxation: objective 4.475000e+02, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  447.50000    0    1  485.00000  447.50000  7.73%     -    0s
# H    0     0                     465.0000000  447.50000  3.76%     -    0s
#      0     0  447.50000    0    1  465.00000  447.50000  3.76%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 10 (of 10 available processors)
#
# Solution count 2: 465 485
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.650000000000e+02, best bound 4.650000000000e+02, gap 0.0000%
# 1 RangeSet Declarations
#     IDXt : Dimen=1, Size=6, Bounds=(1, 6)
#         Key  : Finite : Members
#         None :   True :   [1:6]
#
# 5 Param Declarations
#     C : Size=1, Index=None, Domain=Any, Default=None, Mutable=False
#         Key  : Value
#         None :    25
#     d : Size=6, Index=IDXt, Domain=Any, Default=None, Mutable=False
#         Key : Value
#           1 :    10
#           2 :    40
#           3 :    20
#           4 :     5
#           5 :     5
#           6 :    15
#     f : Size=6, Index=IDXt, Domain=Any, Default=None, Mutable=False
#         Key : Value
#           1 :    50
#           2 :    50
#           3 :    50
#           4 :    50
#           5 :    50
#           6 :    50
#     h : Size=6, Index=IDXt, Domain=Any, Default=None, Mutable=False
#         Key : Value
#           1 :     2
#           2 :     2
#           3 :     2
#           4 :     2
#           5 :     2
#           6 :     2
#     p : Size=6, Index=IDXt, Domain=Any, Default=None, Mutable=False
#         Key : Value
#           1 :     1
#           2 :     3
#           3 :     3
#           4 :     1
#           5 :     1
#           6 :     1
#
# 3 Var Declarations
#     s : Size=6, Index=IDXt
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           1 :     0 :  15.0 :  None : False : False : NonNegativeReals
#           2 :     0 :   0.0 :  None : False : False : NonNegativeReals
#           3 :     0 :   5.0 :  None : False : False : NonNegativeReals
#           4 :     0 :   0.0 :  None : False : False : NonNegativeReals
#           5 :     0 :  15.0 :  None : False : False : NonNegativeReals
#           6 :     0 :   0.0 :  None : False : False : NonNegativeReals
#     x : Size=6, Index=IDXt
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           1 :     0 :   1.0 :     1 : False : False : Binary
#           2 :     0 :   1.0 :     1 : False : False : Binary
#           3 :     0 :   1.0 :     1 : False : False : Binary
#           4 :     0 :   0.0 :     1 : False : False : Binary
#           5 :     0 :   1.0 :     1 : False : False : Binary
#           6 :     0 :   0.0 :     1 : False : False : Binary
#     y : Size=6, Index=IDXt
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           1 :     0 :  25.0 :  None : False : False : NonNegativeReals
#           2 :     0 :  25.0 :  None : False : False : NonNegativeReals
#           3 :     0 :  25.0 :  None : False : False : NonNegativeReals
#           4 :     0 :   0.0 :  None : False : False : NonNegativeReals
#           5 :     0 :  20.0 :  None : False : False : NonNegativeReals
#           6 :     0 :   0.0 :  None : False : False : NonNegativeReals
#
# 1 Objective Declarations
#     obj : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : minimize : y[1] + 2*s[1] + 50*x[1] + 3*y[2] + 2*s[2] + 50*x[2] + 3*y[3] + 2*s[3] + 50*x[3] + y[4] + 2*s[4] + 50*x[4] + y[5] + 2*s[5] + 50*x[5] + y[6] + 2*s[6] + 50*x[6]
#
# 2 Constraint Declarations
#     balance : Size=6, Index=IDXt, Active=True
#         Key : Lower : Body                      : Upper : Active
#           1 :   0.0 :        y[1] - (10 + s[1]) :   0.0 :   True
#           2 :   0.0 : s[1] + y[2] - (40 + s[2]) :   0.0 :   True
#           3 :   0.0 : s[2] + y[3] - (20 + s[3]) :   0.0 :   True
#           4 :   0.0 :  s[3] + y[4] - (5 + s[4]) :   0.0 :   True
#           5 :   0.0 :  s[4] + y[5] - (5 + s[5]) :   0.0 :   True
#           6 :   0.0 : s[5] + y[6] - (15 + s[6]) :   0.0 :   True
#     production_limit : Size=6, Index=IDXt, Active=True
#         Key : Lower : Body           : Upper : Active
#           1 :  -Inf : y[1] - 25*x[1] :   0.0 :   True
#           2 :  -Inf : y[2] - 25*x[2] :   0.0 :   True
#           3 :  -Inf : y[3] - 25*x[3] :   0.0 :   True
#           4 :  -Inf : y[4] - 25*x[4] :   0.0 :   True
#           5 :  -Inf : y[5] - 25*x[5] :   0.0 :   True
#           6 :  -Inf : y[6] - 25*x[6] :   0.0 :   True
#
# 12 Declarations: IDXt d f p h C y s x obj balance production_limit
#
# Problem:
# - Name: x19
#   Lower bound: 465.0
#   Upper bound: 465.0
#   Number of objectives: 1
#   Number of constraints: 13
#   Number of variables: 19
#   Number of binary variables: 6
#   Number of integer variables: 6
#   Number of continuous variables: 13
#   Number of nonzeros: 30
#   Sense: minimize
# Solver:
# - Status: ok
#   Return code: 0
#   Message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#   Termination condition: optimal
#   Termination message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#   Wall time: 0.0023729801177978516
#   Error rc: 0
#   Time: 0.08643984794616699
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
